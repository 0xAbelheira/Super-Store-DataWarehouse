# %%
import pandas as pd

df_stock=pd.read_csv('Stock_History.csv')
df_transactions=pd.read_csv('Sample-Superstore.csv',encoding='windows-1252')

pd.set_option('display.max_columns', None)

# %%
df_transactions.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df_transactions_product = df_transactions[df_transactions['Product ID'] == 'FUR-BO-10001798']
# Certifique-se de que a coluna 'Order Date' está no formato datetime
df_transactions_product['Order Date'] = pd.to_datetime(df_transactions['Order Date'])

# Ordenar o DataFrame pela coluna 'Order Date'
df_transactions__product_sorted = df_transactions_product.sort_values(by='Order Date')

# Exibir as primeiras linhas do DataFrame ordenado
df_transactions__product_sorted.head()
# Out:
# /var/folders/t4/3szz82nx3pqg5dxmwdcj_4dw0000gn/T/ipykernel_17427/2380510934.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transactions_product['Order Date'] = pd.to_datetime(df_transactions['Order Date'])
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 5399    5400  CA-2016-117681 2016-04-09   4/14/2016  Standard Class
# 0          1  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 9334    9335  CA-2017-110198 2017-05-01    5/2/2017     First Class
# 8634    8635  CA-2017-159793 2017-08-25   8/29/2017  Standard Class
#
#      Customer ID    Customer Name   Segment        Country           City  \
# 5399    HF-14995  Herbert Flentye  Consumer  United States    Los Angeles
# ...
